# %% [markdown]
# # Keynote Slides and
# # This Notebook -- Introduction to Jupyter Notebook

# %%
#%matplotlib osx
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 3*np.pi, 100)   #0: starting point; 3*pi: endpoint; 500: number of points, evenly spaced)
# print (type(x))
# print(x.shape)
# print(x)
y = np.sin(x)
y2 = np.sin(x**2)
# print("y:", y)
plt.plot(x, y, 'r-')
plt.plot(x, y2, 'b--')
# plt.title('A simple chirp')
plt.show()

# %%
'''If you want to be fancy...Don't try this at home yet!'''
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['text.usetex'] = True

y = np.linspace(1e-6, 15, 1000)  #why do I start at 1e-6 and not 0?
b = y**3/(np.exp(y)-1)
plt.plot(y, b, lw = 2)
plt.xlabel(r'$Frequencey$', fontsize = 15)
plt.ylabel(r'$Energy\, Density$', fontsize = 15)
## \displaystyle is necessary for showing symbols in quotient the same size as other symbols.
plt.text(5., 1.2, r'$\displaystyle B(f, T) = \frac{y^3}{e^y-1},\, y = hf/kT$', 
         fontsize = 15, color = 'b')
plt.title(r'$\mathrm{Black\, Body\, Spectrum}$', fontsize = 20)
plt.savefig('test.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-08ecbda6597f> in <module>()
#      15          fontsize = 15, color = 'b')
#      16 plt.title(r'$\mathrm{Black\, Body\, Spectrum}$', fontsize = 20)
# ---> 17 plt.savefig('test.pdf')
#      18 plt.show()
#      19
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1812             self.set_frameon(frameon)
#    1813
# -> 1814         self.canvas.print_figure(fname, **kwargs)
#    1815
#    1816         if frameon:
#
# ...

# %%
from IPython.display import HTML

# %%
from IPython.display import Image
Image(url = 'http://www.lawrencehallofscience.org/static/scienceview/scienceview.berkeley.edu/html/view/view_assets/images/newview.jpg')
# Out:
# <img src="http://www.lawrencehallofscience.org/static/scienceview/scienceview.berkeley.edu/html/view/view_assets/images/newview.jpg"/>

# %%
from IPython.display import HTML
HTML('<iframe src=https://en.wikipedia.org/wiki/Main_Page/?useformat=mobile width=700 height=350></iframe>')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('anwy2MPT5RE')
#there are subtleties you have to watch a few times to get or read the script: http://www.ibras.dk/montypython/episode25.htm#10

# %%
#what's IPython.display?
IPython.display??

# %%
import IPython.core.display

# %%
IPython.display??

# %% [raw]
# Can't get questions about IPython.display answered because IPython.display is not a real module.  All it does is 3 imports.
#
# from IPython.core.display import *
# from IPython.core.displaypub import *
# from IPython.lib.display import *
#
# IPython.core.display *is* a real module.  (You can say that that we didn't get a response before importing IPython.core.display is a bug.)

# %% [markdown]
# # 底下的删除

# %%
isinstance(233., float)
# Out:
# True

# %%
string = 'Python'
string[:8]
# Out:
# 'Python'

# %%
len("sdc")
# Out:
# 3

# %%
del string

# %%
string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b80fa55b1234> in <module>()
# ----> 1 string
#
# NameError: name 'string' is not defined
